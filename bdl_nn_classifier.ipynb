# %% [markdown]
# Configuracion y chequeo del entorno

# %% [markdown]
# Conectar con Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Instalacion de modulos y bibliotecas

# %%
import tensorflow as tf
print("Tensorflow version " + tf.__version__)
import tensorflow_probability as tfp
import os
import cv2
import zipfile
import numpy as np
from sklearn.model_selection import train_test_split

from tensorflow import keras
from tensorflow.keras import layers
# Out:
# Tensorflow version 2.9.2

# %% [markdown]
# Armado de la red neuronal - convolucional

# %%
#preprocesamiento de las imagenes // se debe cambiar la carpeta!
trainpath_source = "/content/drive/MyDrive/Master/Bioinformatica/BDL/CatsAndDogs.zip"
files_path = "/content"
trainpath = "/content/train"

# %%
with zipfile.ZipFile(trainpath_source, 'r') as zipp:
  zipp.extractall(files_path)

# %%
# !ls /content/train | wc -l
# Out:
# 25000

# %%
images = []
labels = []

for image in os.scandir(trainpath):
  img = cv2.imread(trainpath+"/"+image.name)           #leo las imagenes desde la carpeta
  img_mtx = cv2.resize(img, (180,180))            #transformo a mismo tamaño, classe narray
  images.append(list(img_mtx))
  if image.name.startswith("cat"):
    lebel = 0
  elif image.name.startswith("dog"):
    lebel = 1
  labels.append(lebel)

#images = tf.data.Dataset.from_tensor_slices(images)

# %%
X = np.array(images)
Y = np.array(labels)

# %%
#separo las imagenes en train y testeo
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
from sklearn.utils import shuffle
x_train, y_train = shuffle(x_train, y_train, random_state=True)

# %%
#convertimos a one hot encoding
y_test_he = tf.one_hot(y_test,2)
y_train_he = tf.one_hot(y_train,2)

# %%
# eliminamos de memoria lo que ya no se va a usar
del images, labels, X, Y, y_train, y_test

# %%
#modificacion de las imagenes de forma aleatoria para generar mayor diversidad y evitar baias y armado de la estructura neuronal
model = tf.keras.Sequential([
                 keras.layers.RandomFlip('horizontal',input_shape=(180, 180, 3)), #rota imagen
                 keras.layers.RandomRotation(0.15),                               #rota imagen
                 keras.layers.RandomZoom(0.2),                                    #zoom imagen
                 keras.layers.RandomWidth(0.1),                                   #ensancha imagen
                 keras.layers.RandomHeight(0.1),                                  #alarga imagen
])
model.add(layers.Conv2D(32, (5,5), strides=(2,2), padding="same", activation="relu", input_shape=(180,180,3)))
model.add(layers.MaxPool2D(pool_size=(2,2), strides=(1,1)))
model.add(layers.Conv2D(48, (3,3), strides=(2,2), padding="same", activation="relu"))
model.add(layers.MaxPool2D(pool_size=(2,2), strides=(1,1)))
model.add(layers.Conv2D(64, (3,3), strides=(1,1)))
model.add(layers.GlobalMaxPooling2D())                                            #es como el flatten(), genera un vector
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.3))                                                    #para quitar overfitting
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(2))                                                        #la salida tiene 2 neuronas porque me dice si es perro o gato

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  random_flip (RandomFlip)    (None, 180, 180, 3)       0
#
#  random_rotation (RandomRota  (None, 180, 180, 3)      0
#  tion)
#
#  random_zoom (RandomZoom)    (None, 180, 180, 3)       0
#
#  random_width (RandomWidth)  (None, 180, None, 3)      0
#
#  random_height (RandomHeight  (None, None, None, 3)    0
#  )
#
#  conv2d (Conv2D)             (None, None, None, 32)    2432
#
#  max_pooling2d (MaxPooling2D  (None, None, None, 32)   0
#  )
#
#  conv2d_1 (Conv2D)           (None, None, None, 48)    13872
#
#  max_pooling2d_1 (MaxPooling  (None, None, None, 48)   0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, None, None, 64)    27712
#
#  global_max_pooling2d (Globa  (None, 64)               0
#  lMaxPooling2D)
#
#  dense (Dense)               (None, 256)               16640
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 126,962
# Trainable params: 126,962
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#para visualizar modelo de forma esquematica
from keras.utils.vis_utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=True)

# %%
#se define la funcion de perdida, de optimizacion y metricas
model.compile(
    optimizer = "adam",
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True), #CategoricalCrossEntropy porque hay mas de una etiqueta y es categorica. Logits=TRUE porque no se uso la funcion de activacion softmax en la capa de salida
    metrics = ["accuracy"],
)

# %%
# se definen los callbacks: early stopper y reduce learning rate

early_stopping = keras.callbacks.EarlyStopping(
    patience = 5,
    min_delta = 0.001,
)

learning_rate_reduction = keras.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=2,
    verbose=1,
    factor=0.5,
    min_lr=0.0001,
)

# %%
# se ajusta el modelo
history = model.fit(
    x_train, y_train_he,
    validation_data=(x_test, y_test_he),
    batch_size = 250,
    epochs = 30,
    callbacks = [early_stopping, learning_rate_reduction]
)
# Out:
# Epoch 1/30
# 80/80 [==============================] - 88s 997ms/step - loss: 1.3568 - accuracy: 0.5327 - val_loss: 0.6702 - val_accuracy: 0.5944 - lr: 0.0010
# Epoch 2/30
# 80/80 [==============================] - 53s 671ms/step - loss: 0.6556 - accuracy: 0.6074 - val_loss: 0.6316 - val_accuracy: 0.6366 - lr: 0.0010
# Epoch 3/30
# 80/80 [==============================] - 48s 604ms/step - loss: 0.6385 - accuracy: 0.6284 - val_loss: 0.6294 - val_accuracy: 0.6450 - lr: 0.0010
# Epoch 4/30
# 80/80 [==============================] - 42s 532ms/step - loss: 0.6148 - accuracy: 0.6614 - val_loss: 0.6056 - val_accuracy: 0.6716 - lr: 0.0010
# Epoch 5/30
# 80/80 [==============================] - 39s 483ms/step - loss: 0.5984 - accuracy: 0.6772 - val_loss: 0.6167 - val_accuracy: 0.6522 - lr: 0.0010
# Epoch 6/30
# 80/80 [==============================] - ETA: 0s - loss: 0.5939 - accuracy: 0.6786
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 80/80 [==============================] - 36s 448ms/step - loss: 0.5939 - accuracy: 0.6786 - val_loss: 0.6525 - val_accuracy: 0.6174 - lr: 0.0010
# Epoch 7/30
# 80/80 [==============================] - 32s 401ms/step - loss: 0.5644 - accuracy: 0.7053 - val_loss: 0.5461 - val_accuracy: 0.7226 - lr: 5.0000e-04
# Epoch 8/30
# 80/80 [==============================] - 33s 414ms/step - loss: 0.5501 - accuracy: 0.7167 - val_loss: 0.5455 - val_accuracy: 0.7276 - lr: 5.0000e-04
# Epoch 9/30
# 80/80 [==============================] - 30s 380ms/step - loss: 0.5454 - accuracy: 0.7214 - val_loss: 0.5403 - val_accuracy: 0.7326 - lr: 5.0000e-04
# Epoch 10/30
# 80/80 [==============================] - 30s 382ms/step - loss: 0.5336 - accuracy: 0.7289 - val_loss: 0.5194 - val_accuracy: 0.7476 - lr: 5.0000e-04
# Epoch 11/30
# 80/80 [==============================] - 28s 355ms/step - loss: 0.5285 - accuracy: 0.7362 - val_loss: 0.5330 - val_accuracy: 0.7330 - lr: 5.0000e-04
# Epoch 12/30
# 80/80 [==============================] - ETA: 0s - loss: 0.5156 - accuracy: 0.7412
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 80/80 [==============================] - 29s 356ms/step - loss: 0.5156 - accuracy: 0.7412 - val_loss: 0.5579 - val_accuracy: 0.7042 - lr: 5.0000e-04
# Epoch 13/30
# 80/80 [==============================] - 27s 345ms/step - loss: 0.5017 - accuracy: 0.7520 - val_loss: 0.4957 - val_accuracy: 0.7612 - lr: 2.5000e-04
# Epoch 14/30
# 80/80 [==============================] - 25s 320ms/step - loss: 0.4982 - accuracy: 0.7542 - val_loss: 0.4936 - val_accuracy: 0.7610 - lr: 2.5000e-04
# Epoch 15/30
# 80/80 [==============================] - 26s 321ms/step - loss: 0.4891 - accuracy: 0.7619 - val_loss: 0.4747 - val_accuracy: 0.7714 - lr: 2.5000e-04
# Epoch 16/30
# 80/80 [==============================] - 25s 306ms/step - loss: 0.4862 - accuracy: 0.7635 - val_loss: 0.4981 - val_accuracy: 0.7568 - lr: 2.5000e-04
# Epoch 17/30
# 80/80 [==============================] - 27s 337ms/step - loss: 0.4865 - accuracy: 0.7606 - val_loss: 0.4706 - val_accuracy: 0.7720 - lr: 2.5000e-04
# Epoch 18/30
# 80/80 [==============================] - 23s 292ms/step - loss: 0.4747 - accuracy: 0.7742 - val_loss: 0.4796 - val_accuracy: 0.7684 - lr: 2.5000e-04
# Epoch 19/30
# 80/80 [==============================] - 23s 283ms/step - loss: 0.4816 - accuracy: 0.7663 - val_loss: 0.4616 - val_accuracy: 0.7756 - lr: 2.5000e-04
# Epoch 20/30
# 80/80 [==============================] - 23s 285ms/step - loss: 0.4731 - accuracy: 0.7694 - val_loss: 0.4701 - val_accuracy: 0.7760 - lr: 2.5000e-04
# Epoch 21/30
# 80/80 [==============================] - 24s 305ms/step - loss: 0.4690 - accuracy: 0.7776 - val_loss: 0.4654 - val_accuracy: 0.7816 - lr: 2.5000e-04
# Epoch 22/30
# 80/80 [==============================] - 23s 293ms/step - loss: 0.4602 - accuracy: 0.7829 - val_loss: 0.4527 - val_accuracy: 0.7870 - lr: 2.5000e-04
# Epoch 23/30
# 80/80 [==============================] - 22s 280ms/step - loss: 0.4592 - accuracy: 0.7801 - val_loss: 0.4658 - val_accuracy: 0.7834 - lr: 2.5000e-04
# Epoch 24/30
# 80/80 [==============================] - 22s 281ms/step - loss: 0.4564 - accuracy: 0.7840 - val_loss: 0.4446 - val_accuracy: 0.7876 - lr: 2.5000e-04
# Epoch 25/30
# 80/80 [==============================] - 23s 284ms/step - loss: 0.4539 - accuracy: 0.7817 - val_loss: 0.4410 - val_accuracy: 0.7946 - lr: 2.5000e-04
# Epoch 26/30
# 80/80 [==============================] - 22s 270ms/step - loss: 0.4486 - accuracy: 0.7900 - val_loss: 0.4514 - val_accuracy: 0.7932 - lr: 2.5000e-04
# Epoch 27/30
# 80/80 [==============================] - 21s 262ms/step - loss: 0.4455 - accuracy: 0.7875 - val_loss: 0.4420 - val_accuracy: 0.7966 - lr: 2.5000e-04
# Epoch 28/30
# 80/80 [==============================] - 23s 292ms/step - loss: 0.4404 - accuracy: 0.7938 - val_loss: 0.4457 - val_accuracy: 0.7944 - lr: 2.5000e-04
# Epoch 29/30
# 80/80 [==============================] - ETA: 0s - loss: 0.4348 - accuracy: 0.7925
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 80/80 [==============================] - 21s 265ms/step - loss: 0.4348 - accuracy: 0.7925 - val_loss: 0.4425 - val_accuracy: 0.7918 - lr: 2.5000e-04
# Epoch 30/30
# 80/80 [==============================] - 21s 257ms/step - loss: 0.4246 - accuracy: 0.7983 - val_loss: 0.4234 - val_accuracy: 0.8082 - lr: 1.2500e-04

# %%
# se evalua el modelo
import pandas as pd
history_df = pd.DataFrame(history.history)
history_df[["accuracy", "val_accuracy"]].plot()
